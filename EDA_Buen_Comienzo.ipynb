# %%
import pandas as pd

df_BC = pd.read_excel(r"C:\Users\DanielGP\OneDrive - Caja de Compensacion Familiar de Antioquia COMFAMA\Tendencias\Personal\Especialización\MATRICULA 10 DICIEMBRE.xlsx")
df_BC.head()
# Out:
#    id_participante    ESTADO                   TIPO_DOCUMENTO IDENTIFICACION  \
# 0           749076  RETIRADO              REGISTRO CIVIL NUIP     1017281872
# 1           795533    ACTIVO              REGISTRO CIVIL NUIP     1021810491
# 2           767354    ACTIVO  PERMISO POR PROTECCION TEMPORAL        7908770
# 3           737262  RETIRADO              REGISTRO CIVIL NUIP     1015198564
# 4           702959    ACTIVO  PERMISO POR PROTECCION TEMPORAL        7212038
#
#   PRIMER_NOMBRE SEGUNDO_NOMBRE PRIMER_APELLIDO SEGUNDO_APELLIDO  \
# 0       AAIZETH            NaN         ESCOBAR          ALVAREZ
# 1       AALIYAH            SKY        CHAVERRA         MARTINEZ
# 2         AARAN           JOSE        QUILOTTE             LUGO
# 3         AARON      ALEJANDRO        GUERRERO         ZAMBRANO
# 4         AARON      ALEJANDRO        QUIÑONES          AGUILAR
#
#   FECHA_NACIMIENTO  EDAD_PARTICIPANTE  ... PARENTESCO_QUIEN_COMPARTE  \
# ...

# %%
df_BC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68247 entries, 0 to 68246
# Columns: 132 entries, id_participante to FAMILIARES.VEREDA_FAMILIAR
# dtypes: datetime64[ns](3), float64(23), int64(10), object(96)
# memory usage: 68.7+ MB

# %%
df_BC.describe()
# Out:
#        id_participante               FECHA_NACIMIENTO  EDAD_PARTICIPANTE  \
# count     68247.000000                          68247       68247.000000
# mean     736394.106173  2017-12-01 04:27:42.877489408           6.542412
# min         165.000000            1975-02-14 00:00:00           0.000000
# 25%      715311.000000            2019-10-03 00:00:00           2.000000
# 50%      757804.000000            2021-01-30 00:00:00           3.000000
# 75%      778452.500000            2022-10-04 00:00:00           5.000000
# max      796006.000000            2024-12-04 00:00:00          49.000000
# std       73025.291945                            NaN           9.230637
#
#             ESTRATO        COMUNA        BARRIO  CORREGIMIENTO        VEREDA  \
# count  67923.000000  57899.000000  57579.000000   10154.000000  10085.000000
# mean       1.904863      7.459317    775.911565      71.021568   7135.905900
# min        1.000000      1.000000      0.000000      13.000000   1316.000000
# ...

# %%
df_BC.isna().sum().sort_values(ascending=False)
# Out:
# MUNICIPIO_DESPLAZAMIENTO      68247
# PARENTESCO_QUIEN_COMPARTE     68247
# PESO_GESTACION                68247
# CAJA_COMPENSACION_FAMILIAR    68197
# NUMERO_DE_VACUNAS             68053
#                               ...
# FECHA_MATRICULA                   0
# PRESTADOR_ID                      0
# ID_SEDE-2                         0
# ID_CONTRATO                       0
# FAMILIARES.ID_PARTICIPANTE        0
# Length: 132, dtype: int64
